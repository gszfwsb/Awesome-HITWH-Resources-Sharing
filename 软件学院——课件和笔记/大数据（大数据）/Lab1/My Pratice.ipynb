# %% [markdown]
# # Just feel free to have a practice on this notebook

# %%
import pandas as pd

# %%
d = {'col1': [1, 2], 'col2': [3, 4]}

# %%
df = pd.DataFrame(data=d)

# %%
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
print("let us have a practice Python programming with notebook here")
# Out:
# let us have a practice Python programming with notebook here
