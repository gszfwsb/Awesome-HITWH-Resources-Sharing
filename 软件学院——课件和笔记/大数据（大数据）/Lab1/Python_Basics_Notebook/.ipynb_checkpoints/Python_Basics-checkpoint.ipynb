# %% [markdown]
# # Python Basics Tutorial
#
#
# This notebook will just go through the Paython basic topics in order:
#
# * Data types
#     * Numbers
#     * Strings
#     * Printing
#     * Lists
#     * Dictionaries
#     * Booleans
#     * Tuples
#     * Sets
# * Comparison Operators
# * if,elif, else Statements
# * for Loops
# * while Loops
# * range()
# * list comprehension
# * functions
# * lambda expressions
# * map and filter
# * methods
#
# You may feel free to try and practise Python here.

# %% [markdown]
# ## Data types
#
# ### Numbers

# %%
1 + 1
# Out:
# 2

# %%
1 * 3
# Out:
# 3

# %%
1 / 2

# %%
2 ** 4

# %%
4 % 2

# %%
5 % 2

# %%
(2 + 3) * (5 + 5)

# %% [markdown]
# ### Variable Assignment

# %%
# Can not start with number or special characters
name_of_var = 2

# %%
x = 2
y = 3

# %%
z = x + y

# %%
z

# %% [markdown]
# ### Strings

# %%
'single quotes'

# %%
"double quotes"

# %%
" wrap lot's of other quotes"

# %% [markdown]
# ### Printing

# %%
x = 'hello'

# %%
x

# %%
print(x)

# %%
num = 12
name = 'Sam'

# %%
print('My number is: {one}, and my name is: {two}'.format(one=num,two=name))

# %%
print('My number is: {}, and my name is: {}'.format(num,name))

# %% [markdown]
# ### Lists

# %%
[1,2,3]

# %%
['hi',1,[1,2]]

# %%
my_list = ['a','b','c']

# %%
my_list.append('d')

# %%
my_list

# %%
my_list[0]

# %%
my_list[1]

# %%
my_list[1:]

# %%
my_list[:1]

# %%
my_list[0] = 'NEW'

# %%
my_list

# %%
nest = [1,2,3,[4,5,['target']]]

# %%
nest[3]

# %%
nest[3][2]

# %%
nest[3][2][0]

# %% [markdown]
# ### Dictionaries

# %%
d = {'key1':'item1','key2':'item2'}

# %%
d

# %%
d['key1']

# %% [markdown]
# ### Booleans

# %%
True

# %%
False

# %% [markdown]
# ### Tuples

# %%
t = (1,2,3)

# %%
t[0]

# %%
t[0] = 'NEW'

# %% [markdown]
# ### Sets

# %%
{1,2,3}

# %%
{1,2,3,1,2,1,2,3,3,3,3,2,2,2,1,1,2}

# %% [markdown]
# ## Comparison Operators

# %%
1 > 2

# %%
1 < 2

# %%
1 >= 1

# %%
1 <= 4

# %%
1 == 1

# %%
'hi' == 'bye'

# %% [markdown]
# ## Logic Operators

# %%
(1 > 2) and (2 < 3)

# %%
(1 > 2) or (2 < 3)

# %%
(1 == 2) or (2 == 3) or (4 == 4)

# %% [markdown]
# ## if,elif, else Statements

# %%
if 1 < 2:
    print('Yep!')

# %%
if 1 < 2:
    print('yep!')

# %%
if 1 < 2:
    print('first')
else:
    print('last')

# %%
if 1 > 2:
    print('first')
else:
    print('last')

# %%
if 1 == 2:
    print('first')
elif 3 == 3:
    print('middle')
else:
    print('Last')

# %% [markdown]
# ## for Loops

# %%
seq = [1,2,3,4,5]

# %%
for item in seq:
    print(item)

# %%
for item in seq:
    print('Yep')

# %%
for jelly in seq:
    print(jelly+jelly)

# %% [markdown]
# ## while Loops

# %%
i = 1
while i < 5:
    print('i is: {}'.format(i))
    i = i+1

# %% [markdown]
# ## range()

# %%
range(5)

# %%
for i in range(5):
    print(i)

# %%
list(range(5))

# %% [markdown]
# ## list comprehension

# %%
x = [1,2,3,4]

# %%
out = []
for item in x:
    out.append(item**2)
print(out)

# %%
[item**2 for item in x]

# %% [markdown]
# ## functions

# %%
def my_func(param1='default'):
    """
    Docstring goes here.
    """
    print(param1)

# %%
my_func

# %%
my_func()

# %%
my_func('new param')

# %%
my_func(param1='new param')

# %%
def square(x):
    return x**2

# %%
out = square(2)

# %%
print(out)

# %% [markdown]
# ## lambda expressions

# %%
def times2(var):
    return var*2

# %%
times2(2)

# %%
lambda var: var*2

# %% [markdown]
# ## map and filter

# %%
seq = [1,2,3,4,5]

# %%
map(times2,seq)

# %%
list(map(times2,seq))

# %%
list(map(lambda var: var*2,seq))

# %%
filter(lambda item: item%2 == 0,seq)

# %%
list(filter(lambda item: item%2 == 0,seq))

# %% [markdown]
# ## methods

# %%
st = 'hello my name is Sam'

# %%
st.lower()

# %%
st.upper()

# %%
st.split()

# %%
tweet = 'Go Sports! #Sports'

# %%
tweet.split('#')

# %%
tweet.split('#')[1]

# %%
d

# %%
d.keys()

# %%
d.items()

# %%
lst = [1,2,3]

# %%
lst.pop()

# %%
lst

# %%
'x' in [1,2,3]

# %%
'x' in ['x','y','z']

# %% [markdown]
# # Great Job!
